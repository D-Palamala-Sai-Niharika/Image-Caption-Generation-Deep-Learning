# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/glove6b50dtxt/glove.6B.50d.txt
# /kaggle/input/flickr8k/Flickr8k_text/ExpertAnnotations.txt
# /kaggle/input/flickr8k/Flickr8k_text/readme.txt
# /kaggle/input/flickr8k/Flickr8k_text/Flickr_8k.devImages.txt
# /kaggle/input/flickr8k/Flickr8k_text/Flickr8k.lemma.token.txt
# /kaggle/input/flickr8k/Flickr8k_text/Flickr_8k.testImages.txt
# /kaggle/input/flickr8k/Flickr8k_text/Flickr8k.token.txt
# /kaggle/input/flickr8k/Flickr8k_text/Flickr_8k.trainImages.txt
# /kaggle/input/flickr8k/Flickr8k_text/CrowdFlowerAnnotations.txt
# /kaggle/input/flickr8k/Flickr8k_Dataset/3226254560_2f8ac147ea.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/214543992_ce6c0d9f9b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2366643786_9c9a830db8.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3368819708_0bfa0808f8.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2190227737_6e0bde2623.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2752809449_632cd991b3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3097776588_312932e438.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1206506157_c7956accd5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1319634306_816f21677f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2465218087_fca77998c6.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3351493005_6e5030f596.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2949337912_beba55698b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/534886684_a6c9f40fa1.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3543600125_223747ef4c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2174206711_11cb712a8d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/280706862_14c30d734a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2100735137_05c6079537.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3131632154_098f86f4cb.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2236016316_f476cbbf06.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3335375223_b4da8df523.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/929679367_ff8c7df2ee.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/241347214_5f19e7998c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2998024845_1529c11694.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1317292658_ba29330a0b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2521938720_911ac092f7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3426933951_2302a941d8.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2410399168_1462c422d4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2587106431_1cc0e719c6.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2339516180_12493e8ecf.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1827560917_c8d3c5627f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2623247254_3bfc795121.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2813588204_69fe7deb14.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3396043950_12783c5147.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3356284586_21c6f155a5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/618771382_459bb492e4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3411393875_a9ff73c67a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3046431231_dc48851062.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3126795109_73920ed5dc.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2199200615_85e4c2a602.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1460352062_d64fb633e0.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3590739067_58baffb3a7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2911238432_33ec2d8cec.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/255741044_1102982213.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3619416477_9d18580a14.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3165936115_cb4017d94e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3724718895_bd03f4a4dc.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3122773470_b622205948.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2447289477_e888df561d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3518755601_cebf11e515.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3265864834_e0229020dd.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2930580341_d36eec8e3c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3616846215_d61881b60f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/290019324_23582048d4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2665461736_595c87f0a3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2245914678_1f82fc3d80.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2392460773_2aa01eb340.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/543102698_38e7e38bbc.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3163323414_d1ce127aa6.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/506738508_327efdf9c3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/860928274_744d14f198.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/825918657_d92f1761f4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2658360285_a0ec74ef48.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2903617548_d3e38d7f88.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2611651553_61f859837e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/747921928_48eb02aab2.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3354489242_dd529ffa1f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3260214530_7179346407.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2607462776_78e639d891.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/757332692_6866ae545c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3317960829_78bbfafbb6.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/486917990_72bd4069af.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2911552402_5166bc173b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2079554580_f18d5c181b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/179009558_69be522c63.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3605061440_1d08c80a57.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3553225222_f5ebe44af1.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3206919175_e3a11b6874.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2393264648_a280744f97.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/241347823_6b25c3e58e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2635400219_2e1a984fd3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3497238310_2abde3965d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3471841031_a949645ba8.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3163198309_bbfe504f0a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3005126574_49c28ffbee.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2533414541_362bf043bb.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/525538142_7348f0bce7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2987121689_f9de6c479b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3318995586_c2bc50b92e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2872743471_30e0d1a90a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/848293676_98e73c52c1.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2955985301_e4139bc772.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/897621891_efb1e00d1d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3232030272_b2480a5fe7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1002674143_1b742ab4b8.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2363100645_c3423a0433.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2987576188_f82304f394.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2085726719_a57a75dbe5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2102315758_a9148a842f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2847615962_c330bded6e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3500139659_b2a60b0141.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2205088706_d7e633e00d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2921670682_6a77a6c3e9.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3226541300_6c81711e8e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2768972186_92787cd523.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2172526745_649f420569.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3182121297_38c99b2769.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1337792872_d01a390b33.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/811663364_4b350a62ce.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2797511323_bf20acab45.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3344948183_5b89379585.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/574274795_57e0834e7d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3497224764_6e17544e0d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/892340814_bdd61e10a4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2690702549_cf81da8cf6.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3029715635_43ab414dfb.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/412203580_2c7278909c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2369248869_0266760c4a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3676460610_8c52e8a355.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/520491467_54cbc0a866.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2593406865_ab98490c1f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/241347391_4fcd4639f4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3249062399_0dafe5e4f5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2689491604_d8760f57b4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3473264983_67917a931f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/418667611_b9995000f4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2567812221_30fb64f5e9.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3025513877_1a6160070d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3080891382_edf83dde18.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/72218201_e0e9c7d65b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3694064560_467683205b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/823675317_b5fbdb17b3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3296584432_bef3c965a3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2244613488_4d1f9edb33.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2913818905_8e4d9aa82a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3382679230_baef3d1eaa.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/246901891_4c4ea49c3a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3497069793_2d4baf5b4b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/661546153_9d30db6984.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/61209225_8512e1dad5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2761599088_8b39cc5f41.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2322601965_748d59dc57.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2839932205_3c9c27cd99.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3405759441_fb31c80240.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2782850287_1408f7ec43.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3406409018_03de95181e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3273625566_2454f1556b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3638783120_f600ceb19d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/799431781_65dc312afc.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2228022180_9597b2a458.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3618932839_acd7d2c2ea.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2443229844_277cded27d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3441531010_8eebbb507e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/140430106_2978fda105.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2394763838_99d1435b85.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3703960010_1e4c922a25.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2930622766_fa8f84deb1.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3182258223_5b9c8a8c55.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3050606344_af711c726c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3592968286_b63c81bcd2.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1772859261_236c09b861.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1810651611_35aae644fb.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3232470286_903a61ea16.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/237953705_cfe6999307.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3431860810_44277cd360.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3608849440_e7d2bed29f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2199793371_343809ff70.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3570800810_978c993133.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/318667317_108c402140.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2208631481_3e4a5675e1.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/639865690_d66d480879.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3504881781_6a842e043b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2635938723_11b85e6763.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2226587791_66e29dd01d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/963730324_0638534227.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3223055565_68973f5d20.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2194286203_5dc620006a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/166433861_70b66cd381.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2308256827_3c0a7d514d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2976684095_ce7ccfd423.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3292277400_f95cdd13d1.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3457045393_2bbbb4e941.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3356369156_074750c6cc.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2495394666_2ef6c37519.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/470373679_98dceb19e7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2512876666_9da03f9589.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/102351840_323e3de834.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3639845565_be547c38ba.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3016606751_0e8be20abd.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2076906555_c20dc082db.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2698197294_ccd9327ef6.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3104400277_1524e4f758.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3225296260_2ee72b4917.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2642474867_4e6346f809.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1770036088_08abe4f6e9.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3657016761_d553e514d9.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3551003620_0b02d76f65.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2751466788_4fab701cc3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3484019369_354e0b88c0.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3726590391_bc6e729bb6.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1420060020_7a6984e2ea.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3186073578_6e115f45f5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2485467050_1d5e2696d4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2873445888_8764699246.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/482088914_e6ea4501e9.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3134586018_ae03ba20a0.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3515665835_22e6fb1193.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2642475077_69d19deb74.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2929506802_5432054d77.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3336361161_c06cdd160e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2942311160_a154104c62.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3119913014_688d4997d7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1620397000_3883e3ecd3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3472540184_b0420b921a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2895403073_906768cafa.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3320209694_db579cb607.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2855417531_521bf47b50.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3147913471_322ea231d9.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3256043809_47258e0b3e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/937559727_ae2613cee5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3273969811_42e9fa8f63.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1511807116_41c3645e8c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3212465975_b657f40eed.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2576878141_87f25a10f0.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2180480870_dcaf5ac0df.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3282434895_1c1efc1475.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3027399066_ca85495775.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3458379941_657182bb09.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1491192153_7c395991e5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3370308329_7f2de5bb58.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3544673666_ffc7483c96.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3119887967_271a097464.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2727051596_be65bfb3d3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2339140905_9f625f140a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/976392326_082dafc3c5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/938162709_21443d352f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/536828916_b763b82949.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/109202756_b97fcdc62c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/173020287_230bfc4ffc.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/262446581_06ef7d9445.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3116769029_f5a76f04ba.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2098418613_85a0c9afea.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2493469969_11b6190615.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/292887910_f34ac101c8.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2830755303_2b5444ab4c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2553550034_5901aa9d6c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3149919755_f9272b10b3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3556037801_3992ce6826.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/391723162_3bdeb7ea33.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2521213787_ca9b5a1758.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/249394748_2e4acfbbb5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3113682377_14fc7b62b0.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3711664623_ef87105ea7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/479807833_85eed6899c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1386251841_5f384a0fea.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2196050115_e236d91f52.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3386060324_b98fdfa449.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2717686269_80c4b5ac9e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3364160101_c5e6c52b25.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/369186134_5eef374112.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/369047365_35476becc9.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2379150102_157d718d1d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2268601066_b018b124fd.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2836808985_b26e4ca09e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3183777589_460a4f445b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3555573680_41c1540a86.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3454754632_977c1523be.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1865794069_6e3a1e57bb.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2731171552_4a808c7d5a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3474999131_788cbf253f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2555622234_3e531e4014.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3631474374_e40764d153.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1296770308_3db2022f5a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2517082705_93bc9f73ec.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3549673305_4dfd44e04a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3603116579_4a28a932e2.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2913965136_2d00136697.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2986716822_e220754d32.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/707972553_36816e53a2.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2508313118_524e93d48c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1446933195_8fe9725d62.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/958326692_6210150354.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/426065353_e9a604a01f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3640348910_fcd627ec66.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2636876892_9353521a1c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2976946039_fb9147908d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3437034427_6df5e9fbf9.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2689001252_e0016c89f0.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2687328779_b4356dab16.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2338627102_6708a9b4fd.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2194495372_bdac7d9e71.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/485245061_5a5de43e20.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3439331800_e71e1d808f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2466171114_3fa51415a7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3256272547_5ae6c66293.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/381239475_044cbffa2b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/113678030_87a6a6e42e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3476381830_3751dd9339.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1434005938_ad75c8598c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3040033126_9f4b88261b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3214885227_2be09e7cfb.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3647446816_bd4383c828.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3690883532_d883f34617.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3691729694_2b97f14c1e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3436259762_43709321ff.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/581419370_30485f3580.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1333888922_26f15c18c3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3655964639_21e76383d0.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3254662117_b2e7dede6e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2633082074_32c85f532c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3189307452_aebc12380b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/308307853_5a51fbdecc.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3712923460_1b20ebb131.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/382701159_f98c1988cd.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2991994607_06f24ec7a6.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3458434150_2b0d619244.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3330680118_4e541889c1.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1273001772_1585562051.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3153067758_53f003b1df.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3351418768_596ef7fd6f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1448511770_1a4a9c453b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2707873672_15e6b5d54b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2728276857_3f83757ef2.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2865376471_43c5e6b941.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1432342377_3e41603f26.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3347666612_659e6e2207.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1153704539_542f7aa3a5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2714699748_c9270dd5aa.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2705793985_007cc703fb.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3306464579_1b16a0caf2.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3110614694_fecc23ca65.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2939197393_93dc64c4bb.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3258396041_69717247f7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2250555512_71670078f5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2977246776_b14be8290d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2273028514_d7b584f73d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3348191949_b0b925e5f1.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2314722788_6262c3aa40.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2713897716_c8cd610360.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2718495608_d8533e3ac5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1402843760_d30f1dbf0f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3300679815_2c6c2301cb.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3523819210_99782628fc.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1397887419_e798697b93.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2830880811_d7f66dd2cf.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/562928217_21f967a807.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2909955251_4b326a46a7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/95151149_5ca6747df6.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2636514498_01fcc5f501.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2466420387_86fe77c966.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3139389284_f01bd4c236.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1453366750_6e8cf601bf.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/78984436_ad96eaa802.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3134341610_3c55e373a7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/343218198_1ca90e0734.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2594042571_2e4666507e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/247652942_29ede19352.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2896483502_6f807bae9e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2916586390_664f0139ea.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3073579130_7c95d16a7f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3225880532_c8d5d1d798.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3736786640_70df13be2c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2246717855_c0c08fe5d2.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2662890367_382eaf83bd.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2519594430_551225e5bd.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/502671104_b2114246c7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3339586622_a7676b30e1.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/222369445_5b6af347dd.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1481062342_d9e34366c4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/820169182_f5e78d7d19.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2615623392_ab2b9759ae.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1321949151_77b77b4617.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3506560025_8d0f4f9ac4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2848977044_446a31d86e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/461019788_bc0993dabd.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2885111681_dc328ecfff.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3143574389_8a4048fbe2.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2476214153_99a3998509.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/460781612_6815c74d37.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2891162278_fbf96be4f4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3687995245_624b54090d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1247181182_35cabd76f3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2525666287_638ab5e784.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3567214106_6ece483f8b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3293751136_b0ce285dc3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2420546021_4a59790da6.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3371887001_44ab0c2f17.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2963672852_c28043bb2c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3155987659_b9ea318dd3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3084011028_d1e2c40d7d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2229179070_dc8ea8582e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3402081035_a54cfab1d9.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3254817653_632e840423.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/441921713_1cafc7d7d2.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3569406219_f37ebf7b92.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3088399255_1bd9a6aa04.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2879241506_b421536330.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2192475933_d779bf42eb.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3380407617_07b53cbcce.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3538686658_30afc75f02.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2068465241_3bcabacfd7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2982928615_06db40f4cd.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3430287726_94a1825bbf.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2222186636_85e03e0b75.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2863848437_f2592ab42d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3288173388_03bc2a844d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2944952557_8484f0da8f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3513265399_a32e8cfd18.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3582689770_e57ab56671.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2853205396_4fbe8d7a73.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3230132205_dccfafa5ee.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3413973568_6630e5cdac.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1303548017_47de590273.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3618504267_d7eaa495d0.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2912476706_9a0dbd3a67.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/561179890_af8e31cb2e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3728164558_52729baefa.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2662262499_3cdf49cedd.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3464871350_3f2d624a9c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3437107047_715c60e9c8.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/531197115_2be4d5034b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/241345981_1ef4f8109c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1466479163_439db855af.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2181724497_dbb7fcb0a9.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2943079526_e9033a6556.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1236964638_1808784a3c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3088922727_4bdf2ccc94.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2442243868_abe8f74fb4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2281768510_9cc5728c55.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/236095034_c983bdfbbf.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3232252882_05db7c2216.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2708582445_5e5999b956.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/495033548_bd320405d8.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2651915425_7a58e862e9.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3558438174_d8f41438a4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2744690159_fe2c89e55b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2579899436_5086a33c7a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3048211972_db71d104c2.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/521658170_a837af87e9.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3522349685_f046f0e250.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2441313372_6a1d59582b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3215081286_d55541aa6b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3528902357_be2357a906.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/501520507_c86f805ab8.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3193335577_9bdbaf9f70.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2610447973_89227ff978.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3174453534_fcc927c647.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3461049169_e068ae4f25.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2053733930_e245615ad4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2615811117_42b1838205.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3500115252_9404c066a8.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3517023411_a8fbd15230.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2427490900_5b7a8874b9.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2086534745_1e4ab80078.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3467219837_7d62213dec.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3516825206_5750824874.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3184891327_8785194e3c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2081615901_13092cac56.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3328495660_ed0e3f29cf.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2059842472_f4fb61ea08.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/460478198_83039f2593.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3185787277_b412d7f5b7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2752084369_52e7867da7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3271385712_ffd34f2de5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2183967273_d182e18cf6.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2868668723_0741222b23.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1801063894_60bce29e19.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/189721896_1ffe76d89e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/186890601_8a6b0f1769.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2156726763_034ecd2e39.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2662845514_8620aaee96.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2596475173_58f11fc583.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/244368383_e90b6b2f20.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3717809376_f97611ab84.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1075881101_d55c46bece.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2344699642_4fae2f4e07.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1100214449_d10861e633.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3156406419_38fbd52007.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2897832422_0cbdb1421e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2066048248_f53f5ef5e2.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/492341908_1ef53be265.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3523920786_0eb63993fd.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2496399593_a24954a5ca.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2208055895_37cd8e1edf.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2107838729_a527e434bd.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2271671533_7538ccd556.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/111537217_082a4ba060.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/260162669_c79a900afb.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2243904502_2d265fed80.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/217838128_1f0a84ddc1.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3421129418_088af794f7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3235746553_a40416c00e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2089426086_7acc98a3a8.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/191003284_1025b0fb7d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/140377584_12bdbdf2f8.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2942798367_022df04b49.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3559781965_d4ec00e506.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2602415701_7674eb19e4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2596514158_c516e57974.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3209523192_05a4cef844.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/391579205_c8373b5411.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/364213568_7f83e7d144.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3357937209_cf4a9512ac.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2937942758_712be5c610.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/757046028_ff5999f91b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/537758332_8beb9cf522.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3537474810_cf676b3259.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2573625591_70291c894a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/222878446_32c6fc4bc9.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2877159456_ea4a46b0d2.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/857914283_270d7d1c87.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3393446245_37dd3f3b59.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1142283988_6b227c5231.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2943023421_e297f05e11.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3283368342_b96d45210e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3514184232_b336414040.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2194494220_bb2178832c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3350260112_fcb47ff6b2.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/551403320_dfdcf9fc3b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2732625904_4fbb653434.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2223382277_9efa58ec45.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2616561200_ea079f285a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/534875358_6ea30d3091.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/314904143_5a216a192b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/414568315_5adcfc23c0.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3392851587_a638ff25e2.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2325258180_6217dd17eb.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3656906086_7034f69ab6.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3293642024_e136b74a55.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/280932151_ae14a67be5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/426920445_d07d1fd0f7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3486538055_bcf4d3dfda.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2591110592_ef5f54f91c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2574194729_1f099647ee.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2588927489_f4da2f11ec.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2665264979_df9c284bf8.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/979201222_75b6456d34.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3043266735_904dda6ded.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1526325728_74eb4153d8.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2789688929_9424fceed1.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3029472296_d429b1586c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3399618896_9ef60cd32c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3388094307_5a83be64a5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2877424957_9beb1dc49a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3474330484_a01d8af624.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/447111935_5af98563e3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/452345346_afe1248586.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/287999021_998c2eeb91.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1998457059_c9ac9a1e1a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2864340145_d28b842faf.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3218861747_5c5c547b66.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3171035252_dba286ae5c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2657484970_610e18144f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3313620862_0c65c645f5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/172092461_a9a9762e13.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3331009729_d3b14738e6.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/293327462_20dee0de56.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2947274789_a1a35b33c3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3516653997_98ec551a67.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3174726084_c108de0a64.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/837919879_94e3dacd83.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3703035378_c6034cac51.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/323657582_b6b6d8f7bd.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1433577867_39a1510c43.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/511749704_3037806cb1.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3103185190_eb8729c166.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3154709407_9b0778cbeb.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2967549094_d32422eb01.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3225058391_a12d38d911.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3590647207_2d4ec3f52c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2665586311_9a5f4e3fbe.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/247618600_239eeac405.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2339573065_91f1e3be60.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3527926597_45af299eee.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2255332561_3375897ff0.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3601491447_a338875b51.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/512031915_0dd03dcdf9.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2393971707_bce01ae754.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/300314926_0b2e4b64f5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/530454257_66d58b49ee.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3709030554_02301229ea.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2675190069_d5c3b2c876.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3335547029_74d620fa6c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2878705136_609dfbf318.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3759230208_1c2a492b12.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3375549004_beee810e60.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1149179852_acad4d7300.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2880874989_a33b632924.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1160034462_16b38174fe.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2526041608_a9775ab8d7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/336551615_a01418bc53.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3523874798_9ba2fa46e3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3665179773_dd217416fc.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3726168984_1fa2c8965b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3177298173_78cea31d64.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2426828433_ce894d1c54.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3679341667_936769fd0c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2787868417_810985234d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2206600240_f65df56a09.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2247138288_7355861203.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/804087017_330bcc8c56.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3436074878_21515a6706.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1923476156_e20976b32d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2453971388_76616b6a82.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/485357535_b45ba5b6da.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2768021570_46bc6325e3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3549011001_26cace3646.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/279728508_6bd7281f3c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3006217970_90b42e6b27.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2328104318_5a43ca170c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3680031186_c3c6698f9d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2544426580_317b1f1f73.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2198964806_c57b0534d3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2896298341_92d718366a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2527303359_6c3dc3f282.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2578161080_e007c9177a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3665569615_9a71c4b6e4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2603690144_7a28b1d13c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2067833088_04e84e5bf2.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3178371973_60c6b8f110.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/543363241_74d8246fab.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1936215201_d03a75cbba.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1777816180_08d7e8063b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/265528702_8653eab9fa.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2992658871_ac786d37a6.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3013469764_30e84e9a0d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/260231029_966e2f1727.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2261169495_98254e2e66.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/129599450_cab4e77343.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1423126855_6cd2a3956c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1248940539_46d33ed487.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3441701164_6dbbdf1bce.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3173461705_b5cdeef1eb.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2975018306_0e8da316f5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3426724811_137855b4f7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/559102835_472ff702b5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1461667284_041c8a2475.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3535372414_4c51c86fc4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2891185857_54942809cf.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2619454551_c4bb726a85.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/510197538_0a11b94460.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2612608861_92beaa3d0b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/487487795_54705c406e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2846037553_1a1de50709.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3279025792_23bfd21bcc.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/778885185_3f6905370b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/241347114_6273736da8.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2451988767_244bff98d1.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3245266444_2e798096e6.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1236951314_0308dc4138.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2603792708_18a97bac97.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3639617775_149001232a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2854234756_8c0e472f51.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3263141261_db3a4798b5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/530950375_eea665583f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3485486737_953f9d3be2.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/487071033_27e460a1b9.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2644916196_16f91dae54.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/141139674_246c0f90a1.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3014080715_f4f0dbb56e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2800758232_d7fa598065.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/397725001_e51f7c391c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1095980313_3c94799968.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2426303900_0a8d52eb14.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1994416869_4dd769a806.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2429978680_1e18a13835.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3171066023_ec60ba30f3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2632111399_b3c1630f8e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2344875609_8e172d682b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2125216241_5b265a2fbc.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2915538325_59e11276dd.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1932314876_9cc46fd054.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2333288869_8c01e4c859.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3515451715_ac5ac04efa.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2597737483_6518a230e4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3281611946_f42deed2e1.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2613209320_edf6a2b7e9.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3420064875_0349a75d69.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3098707588_5096d20397.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1508269285_6c5723f67d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3221036999_3f7b152d8a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3701226275_952547ba0f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2943334864_6bab479a3e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3557295488_600d387347.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2085557551_7a88d01d4e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/236476706_175081ce18.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2753531542_ace2c870b7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3484625231_5b1a1a07b8.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1752454466_723790dbd6.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2737729252_b3fd9c05b1.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2998861375_02817e0147.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3148811252_2fa9490a04.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/269986132_91b71e8aaa.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/207237775_fa0a15c6fe.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2596474836_79468f23a0.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/285306009_f6ddabe687.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2095435987_1b7591d214.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3305895920_100a67d148.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2860372882_e0ef4131d4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3222055946_45f7293bb2.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3343116398_59a5341f7f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3484820303_7be0e914b4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2547785434_f227bd3680.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3257277774_aba333a94c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2925737498_57585a7ed9.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2247192427_5e106f24a9.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/871290666_4877e128c0.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3446586125_cafa0bfd67.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3629664676_36bcefe6b7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2866529477_7e0c053ebc.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3529721084_4b405baf54.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2528521798_fb689eba8d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3178005751_fca19815ac.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2249264723_d08655d9f2.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2678612999_893ed671f8.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3247341210_5d1e50df23.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3526897578_3cf77da99b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2570365455_41cc9a7d2b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2318721455_80c6644441.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2089542487_b4c1ee7025.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3423509305_e399d005db.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3452411712_5b42d2a1b5.jpg
# ...
# /kaggle/input/flickr8k/Flickr8k_Dataset/3266261886_36e1323d2f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2446601467_a35841cb1d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2480664591_e6d22ed61c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3508882611_3947c0dbf5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3384742888_85230c34d5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/450596617_ed37ec0fe4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/288880576_818b6ecfef.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3346614841_698f9aa486.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3255017708_2b02bfcdcf.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/140526327_3cb984de09.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/390992102_67fa31b22f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/435054077_3506dbfcf4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3610683688_bbe6d725ed.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2561212119_1af8cb9b5d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3319489465_c65c91e4f2.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3409740108_1505489537.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/801607443_f15956d1ce.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2934325103_e9b8d7430f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3223709894_97824ba76f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2833431496_09d999db4d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3287969199_08e775d896.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/161905204_247c6ca6de.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3381584882_341ee3092f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3568225554_73cdb19576.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3334953664_a669038795.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3342309960_c694b2cce9.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/128912885_8350d277a4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/295433203_8185c13e08.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2855667597_bf6ceaef8e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/451081733_40218cec31.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/872622575_ba1d3632cc.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/524031846_28b11bc0e5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3658427967_6e2e57458d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/497122685_a51b29dc46.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/370713359_7560808550.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/265223847_636ba039c1.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3537452619_3bd79f24e0.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2451114871_8617ae2f16.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2080033499_6be742f483.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3159641529_c2c74f3eaf.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3530502404_f8c3a3f61c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2892395757_0a1b0eedd2.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3519942322_b37d088aae.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2293424366_7b5fcd2398.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3726700898_c50494b8bd.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1499495021_d295ce577c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/274313927_404d0e94ab.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1383840121_c092110917.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3621652774_fd9634bd5b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3102204862_f1d220230b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2495931537_9b8d4474b6.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2795352290_9209b214f3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/142802798_962a4ec5ce.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3475581086_a533567561.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/543007912_23fc735b99.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/19212715_20476497a3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3259160693_067ec7ebc3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3062173277_bfb5ef4c45.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1252787177_4b08625897.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3421480658_b3518b6819.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/637342973_89f6fac1f7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/241346105_c1c860db0d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3431121650_056db85987.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1937262236_cbf5bfa101.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/503794526_603a7954d3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2038662925_f4fa8c2534.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2695085862_2ed62df354.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2396100671_3a9d67f03d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/146098876_0d99d7fb98.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3211556865_d1d9becf69.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2333584535_1eaf9baf3e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2878578240_caf64c3b19.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3604314527_5077cd9d43.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/766346887_a9a9d0637a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3197891333_b1b0fd1702.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1969573381_5ecfae4c80.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3169777863_d745865784.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2856456013_335297f587.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2287023569_fd7a9c60b8.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3174156702_95a1cda2d9.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2363419943_717e6b119d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1244485675_822e6efe60.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2909609550_070eea49b5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1389323170_d1c81d6b51.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3021318991_fa28e3bca7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/310213587_778fe8fb5b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2466171100_5e60cfcc11.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/693450725_8ad72389e6.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3195969533_98f5de0fab.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3359089834_263e529c71.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3606942887_1159d92548.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3401437960_7da856e004.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/299676757_571ee47280.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2120571547_05cd56de85.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3138562460_44227a35cf.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/145721498_a27d2db576.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3228960484_9aab98b91a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3217910740_d1d61c08ab.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3277824093_299cbb3138.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2584020755_14e2b3e8fc.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2570559405_dc93007f76.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3688839836_ba5e4c24fc.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/295258727_eaf75e0887.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3397220683_4aca010f86.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3419197575_aa5b84a9f0.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3329793486_afc16663cc.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/429205889_ff5a006311.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/299178969_5ca1de8e40.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3029928396_99ac250788.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1427391496_ea512cbe7f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2938747424_64e64784f0.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1389264266_8170bc1c54.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/549887636_0ea5ae4739.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2061144717_5b3a1864f0.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/642987597_03b21a1437.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/298920219_9a3f80acc5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/260520547_944f9f4c91.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3208074567_ac44aeb3f3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/539493431_744eb1abaa.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/875731481_a5a0a09934.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3710353645_8fbfaa4175.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3455920874_6fbec43194.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2303426046_09cfd7bc4e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3673878924_506c9d767b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2431120202_b24fe2333a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3585117340_73e96b6173.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2684489465_32ba1d0344.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2125626631_a4b63af97e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2496236371_61dec88113.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1289142574_2bd6a082dd.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/566446626_9793890f95.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3457572788_e1fe4f6480.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1358892595_7a37c45788.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3106782647_b078830a9e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3101796900_59c15e0edc.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3222250187_ef610f267e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/743571049_68080e8751.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3415003392_139c0f3586.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/254295381_d98fa049f4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3331190056_09f4ca9fd2.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1490213660_9ea45550cf.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3181328245_7c04ce1691.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1417031097_ab656bc4bd.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3276895962_c053263d01.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3692836015_d11180727b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3286406057_a1668655af.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/350176185_b8c5591e36.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3491607076_922ec561d9.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2279980395_989d48ae72.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3437781040_82b06facb3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1387443857_602ab6f9bf.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1248357227_2b4175fc39.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3453284877_8866189055.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3244470342_c08f6bb17e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/330849796_c575c3108a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2687229880_97cfd8148e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2274602044_b3d55df235.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3016726158_4d15b83b06.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2448270671_5e0e391a80.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2188688248_f57a28a5a7.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3430100177_5864bf1e73.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3374223949_90776ba934.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2261962622_e9318a95eb.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3208553539_2bf6c6d162.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2647394564_4843800cff.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/698107542_3aa0ba78b4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/437404867_209625774d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2830309113_c79d7be554.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3724113279_99b6e5bf41.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3681324243_b69fa90842.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/236518934_c62a133077.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3038045802_93f2cd5fbc.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3234719720_5bb2fc5ffa.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3042483842_beb23828b9.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2699426519_228719b1db.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/240583223_e26e17ee96.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2128119486_4407061c40.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2444741900_5cb3ef3e1d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1807169176_7f5226bf5a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/247691240_3881777ab8.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/525968880_82623392d1.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1406010299_5755339f08.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3530504007_3272c57e21.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3694219419_a7a83d4886.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2256138896_3e24b0b28d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/159712188_d530dd478c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3724150944_fc62e8d5e0.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1418266617_b32143275b.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2698614194_b4e6e11dff.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/759015118_4bd3617e60.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1763020597_d4cc8f0f8a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1581822598_0ae23074f1.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/406642021_9ec852eccf.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/899810584_61e1578d3f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2501742763_b2cb322087.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2934837034_a8ca5b1f50.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3677693858_62f2f3163f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2918880895_e61f74f2f0.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3175849727_bf30b892cb.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3704995657_e2e114083d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3339140382_2e49bc324a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2660480624_45f88b3022.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/652542470_60e858da64.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3636543173_15f56515e5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3125158798_0743dae56e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3459492423_c881f12c9f.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3500136982_bf7a85531e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/412101267_7257e6d8c0.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3354883962_170d19bfe4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3549277110_24d4064ccd.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3255732353_fbc487aefc.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3322443827_a04a94bb91.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1579198375_84b18e003a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3330019493_fd36fbc2ea.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3335370208_460fc19bfa.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2774581025_81a3074e2e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3569420080_72fbe84751.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/533713007_bf9f3e25b4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2266142543_b2de18c081.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3074617663_2f2634081d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3249014584_21dd9ddd9d.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3294830188_e46bd9b93c.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3272002857_ace031f564.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3346040664_5b584e6133.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3512033861_a357bb58b6.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/498444334_a680d318a1.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2473791980_805c819bd4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2993167197_e5d0a73530.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3364258732_9942c557e5.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3081363964_d404eccae8.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3684562647_28dc325522.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/1287073593_f3d2a62455.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2543679402_9359e1ee4e.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/608257195_6ec6f48e37.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3374384485_751f719be4.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3189941492_a3f4347b1a.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3674565156_14d3b41450.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/272283076_2d4aa1d5cf.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/281419391_522557ce27.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/590445887_4d4fa43923.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/502115726_927dd684d3.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/3025438110_40af7e6a80.jpg
# /kaggle/input/flickr8k/Flickr8k_Dataset/2623982903_58ec7c5026.jpg

# %% [markdown]
# ## Image Captioning
# - Generating Captions for Images

# %% [markdown]
# ### Steps
# - Data collection
# - Understanding the data
# - Data Cleaning
# - Loading the training set
# - Data Preprocessing — Images
# - Data Preprocessing — Captions
# - Data Preparation using Generator Function
# - Word Embeddings
# - Model Architecture
# - Inference

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras as keras
import re
import nltk
from nltk.corpus import stopwords
import string
import json
from time import time
import pickle
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.resnet import ResNet50, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Dense, Dropout, Embedding, LSTM
from keras.layers.merge import add

# %%
# Read Text Captions

def readTextFile(path):
    with open(path) as f:
        captions = f.read()
    return captions

# %%
captions  = readTextFile("/kaggle/input/flickr8k/Flickr8k_text/Flickr8k.token.txt")
captions = captions.split('\n')[:-1]

# %%
print(len(captions))
# Out:
# 40460

# %%
first,second  = captions[0].split('\t')
print(first.split(".")[0])
print(second)
# Out:
# 1000268201_693b08cb0e
# A child in a pink dress is climbing up a set of stairs in an entry way .

# %%
# Dictionary to Map each Image with the list of captions it has
descriptions = {}

for x in captions:
    first,second = x.split('\t')
    img_name = first.split(".")[0]
    
    #if the image id is already present or not
    if descriptions.get(img_name) is None:
        descriptions[img_name] = []
    
    descriptions[img_name].append(second)

# %%
descriptions["1000268201_693b08cb0e"]
# Out:
# ['A child in a pink dress is climbing up a set of stairs in an entry way .',
#  'A girl going into a wooden building .',
#  'A little girl climbing into a wooden playhouse .',
#  'A little girl climbing the stairs to her playhouse .',
#  'A little girl in a pink dress going into a wooden cabin .']

# %%
IMG_PATH = "/kaggle/input/flickr8k/Flickr8k_Dataset/"
import cv2
import matplotlib.pyplot as plt

img = cv2.imread(IMG_PATH+"1000268201_693b08cb0e.jpg")
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Data Cleaning

# %%
def clean_text(sentence):
    sentence = sentence.lower()
    sentence = re.sub("[^a-z]+"," ",sentence)
    sentence = sentence.split()
    
    sentence  = [s for s in sentence if len(s)>1]
    sentence = " ".join(sentence)
    return sentence

# %%
clean_text("A cat is sitting over the house # 64")
# Out:
# 'cat is sitting over the house'

# %%
# Clean all Captions
for key,caption_list in descriptions.items():
    for i in range(len(caption_list)):
        caption_list[i] = clean_text(caption_list[i])

# %%
descriptions["1000268201_693b08cb0e"]
# Out:
# ['child in pink dress is climbing up set of stairs in an entry way',
#  'girl going into wooden building',
#  'little girl climbing into wooden playhouse',
#  'little girl climbing the stairs to her playhouse',
#  'little girl in pink dress going into wooden cabin']

# %%
# Write the data to text file
with open("descriptions_1.txt","w") as f:
    f.write(str(descriptions))

# %% [markdown]
# ### Vocabulary

# %%
descriptions = None
with open("descriptions_1.txt",'r') as f:
    descriptions= f.read()
    
json_acceptable_string = descriptions.replace("'","\"")
descriptions = json.loads(json_acceptable_string)

# %%
print(type(descriptions))
# Out:
# <class 'dict'>

# %%
# Vocab

vocab = set()
for key in descriptions.keys():
    [vocab.update(sentence.split()) for sentence in descriptions[key]]
    
print("Vocab Size : %d"% len(vocab))
# Out:
# Vocab Size : 8424

# %%
# Total No of words across all the sentences
total_words = []

for key in descriptions.keys():
    [total_words.append(i) for des in descriptions[key] for i in des.split()]
    
print("Total Words %d"%len(total_words))
# Out:
# Total Words 373837

# %%
# Filter Words from the Vocab according to certain threshold frequncy
import collections

counter = collections.Counter(total_words)
freq_cnt = dict(counter)
print(len(freq_cnt.keys()))
# Out:
# 8424

# %%
# Sort this dictionary according to the freq count
sorted_freq_cnt = sorted(freq_cnt.items(),reverse=True,key=lambda x:x[1])

# Filter
threshold = 10
sorted_freq_cnt  = [x for x in sorted_freq_cnt if x[1]>threshold]
total_words = [x[0] for x in sorted_freq_cnt]
print(len(total_words))
# Out:
# 1845

# %% [markdown]
# ### Prepare Train/Test Data

# %%
train_file_data = readTextFile("/kaggle/input/flickr8k/Flickr8k_text/Flickr_8k.trainImages.txt")
test_file_data = readTextFile("/kaggle/input/flickr8k/Flickr8k_text/Flickr_8k.testImages.txt")

# %%
train = [row.split(".")[0] for row in train_file_data.split("\n")[:-1]]
test = [row.split(".")[0] for row in test_file_data.split("\n")[:-1]]

# %%
train[:5]
# Out:
# ['2513260012_03d33305cf',
#  '2903617548_d3e38d7f88',
#  '3338291921_fe7ae0c8f8',
#  '488416045_1c6d903fe0',
#  '2644326817_8f45080b87']

# %%
# Prepare Description for the Training Data
# Tweak - Add <s> and <e> token to our training data
train_descriptions = {}

for img_id in train:
    train_descriptions[img_id] = []
    for cap in descriptions[img_id]:
        cap_to_append = "startseq "  + cap + " endseq"
        train_descriptions[img_id].append(cap_to_append)

# %%
train_descriptions["1000268201_693b08cb0e"]
# Out:
# ['startseq child in pink dress is climbing up set of stairs in an entry way endseq',
#  'startseq girl going into wooden building endseq',
#  'startseq little girl climbing into wooden playhouse endseq',
#  'startseq little girl climbing the stairs to her playhouse endseq',
#  'startseq little girl in pink dress going into wooden cabin endseq']

# %% [markdown]
# ### Transfer Learning
# - Images --> Features
# - Text ---> Features

# %% [markdown]
# ### Step - 1 Image Feature Extraction

# %%
model = ResNet50(weights="imagenet",input_shape=(224,224,3))
model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 1000)         2049000     avg_pool[0][0]
# ==================================================================================================
# Total params: 25,636,712
# Trainable params: 25,583,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
model_new = Model(model.input,model.layers[-2].output)

# %%
def preprocess_img(img):
    img = image.load_img(img,target_size=(224,224))
    img = image.img_to_array(img)
    img = np.expand_dims(img,axis=0)
    # Normalisation
    img = preprocess_input(img)
    return img

# %%
img = preprocess_img(IMG_PATH+"1000268201_693b08cb0e.jpg")
plt.imshow(img[0])
plt.axis("off")
plt.show()

# %%
def encode_image(img):
    img = preprocess_img(img)
    feature_vector = model_new.predict(img)
    
    feature_vector = feature_vector.reshape((-1,))
    #print(feature_vector.shape)
    return feature_vector

# %%
encode_image(IMG_PATH+"1000268201_693b08cb0e.jpg")
# Out:
# array([0.06535928, 0.1678255 , 0.3251769 , ..., 0.05107141, 0.32821223,
#        1.0043367 ], dtype=float32)

# %%
start = time()
encoding_train = {}
#image_id -->feature_vector extracted from Resnet Image

for ix,img_id in enumerate(train):
    img_path = IMG_PATH+"/"+img_id+".jpg"
    encoding_train[img_id] = encode_image(img_path)
    
    if ix%100==0:
        print("Encoding in Progress Time step %d "%ix)
        
end_t = time()
print("Total Time Taken :",end_t-start)
# Out:
# Encoding in Progress Time step 0
# Encoding in Progress Time step 100
# Encoding in Progress Time step 200
# Encoding in Progress Time step 300
# Encoding in Progress Time step 400
# Encoding in Progress Time step 500
# Encoding in Progress Time step 600
# Encoding in Progress Time step 700
# Encoding in Progress Time step 800
# Encoding in Progress Time step 900
# Encoding in Progress Time step 1000
# Encoding in Progress Time step 1100
# Encoding in Progress Time step 1200
# Encoding in Progress Time step 1300
# Encoding in Progress Time step 1400
# Encoding in Progress Time step 1500
# Encoding in Progress Time step 1600
# Encoding in Progress Time step 1700
# Encoding in Progress Time step 1800
# Encoding in Progress Time step 1900
# Encoding in Progress Time step 2000
# Encoding in Progress Time step 2100
# Encoding in Progress Time step 2200
# Encoding in Progress Time step 2300
# Encoding in Progress Time step 2400
# Encoding in Progress Time step 2500
# Encoding in Progress Time step 2600
# Encoding in Progress Time step 2700
# Encoding in Progress Time step 2800
# Encoding in Progress Time step 2900
# Encoding in Progress Time step 3000
# Encoding in Progress Time step 3100
# Encoding in Progress Time step 3200
# Encoding in Progress Time step 3300
# Encoding in Progress Time step 3400
# Encoding in Progress Time step 3500
# Encoding in Progress Time step 3600
# Encoding in Progress Time step 3700
# Encoding in Progress Time step 3800
# Encoding in Progress Time step 3900
# Encoding in Progress Time step 4000
# Encoding in Progress Time step 4100
# Encoding in Progress Time step 4200
# Encoding in Progress Time step 4300
# Encoding in Progress Time step 4400
# Encoding in Progress Time step 4500
# Encoding in Progress Time step 4600
# Encoding in Progress Time step 4700
# Encoding in Progress Time step 4800
# Encoding in Progress Time step 4900
# Encoding in Progress Time step 5000
# Encoding in Progress Time step 5100
# Encoding in Progress Time step 5200
# Encoding in Progress Time step 5300
# Encoding in Progress Time step 5400
# Encoding in Progress Time step 5500
# Encoding in Progress Time step 5600
# Encoding in Progress Time step 5700
# Encoding in Progress Time step 5800
# Encoding in Progress Time step 5900
# Total Time Taken : 1099.55650639534

# %%
# !mkdir saved

# %%
# Store everything to the disk 
with open("saved/encoded_train_features.pkl","wb") as f:
    pickle.dump(encoding_train,f)

# %%
start = time()
encoding_test = {}
#image_id -->feature_vector extracted from Resnet Image

for ix,img_id in enumerate(test):
    img_path = IMG_PATH+"/"+img_id+".jpg"
    encoding_test[img_id] = encode_image(img_path)
    
    if ix%100==0:
        print("Test Encoding in Progress Time step %d "%ix)
        
end_t = time()
print("Total Time Taken(test) :",end_t-start)
# Out:
# Test Encoding in Progress Time step 0
# Test Encoding in Progress Time step 100
# Test Encoding in Progress Time step 200
# Test Encoding in Progress Time step 300
# Test Encoding in Progress Time step 400
# Test Encoding in Progress Time step 500
# Test Encoding in Progress Time step 600
# Test Encoding in Progress Time step 700
# Test Encoding in Progress Time step 800
# Test Encoding in Progress Time step 900
# Total Time Taken(test) : 201.00510382652283

# %%
with open("saved/encoded_test_features.pkl","wb") as f:
    pickle.dump(encoding_test,f)

# %% [markdown]
# ### Data pre-processing for Captions

# %%
# Vocab
len(total_words)
# Out:
# 1845

# %%
word_to_idx = {}
idx_to_word = {}

for i,word in enumerate(total_words):
    word_to_idx[word] = i+1
    idx_to_word[i+1] = word

# %%
#word_to_idx["dog"]
#idx_to_word[1]
print(len(idx_to_word))
# Out:
# 1845

# %%
# Two special words
idx_to_word[1846] = 'startseq'
word_to_idx['startseq'] = 1846

idx_to_word[1847] = 'endseq'
word_to_idx['endseq'] = 1847

vocab_size = len(word_to_idx) + 1
print("Vocab Size",vocab_size)
# Out:
# Vocab Size 1848

# %%
max_len = 0 
for key in train_descriptions.keys():
    for cap in train_descriptions[key]:
        max_len = max(max_len,len(cap.split()))
        
print(max_len)
# Out:
# 35

# %% [markdown]
# ### Data Loader (Generator)

# %%
def data_generator(train_descriptions,encoding_train,word_to_idx,max_len,batch_size):
    X1,X2, y = [],[],[]
    
    n =0
    while True:
        for key,desc_list in train_descriptions.items():
            n += 1
            
            photo = encoding_train[key]
            for desc in desc_list:
                
                seq = [word_to_idx[word] for word in desc.split() if word in word_to_idx]
                for i in range(1,len(seq)):
                    xi = seq[0:i]
                    yi = seq[i]
                    
                    #0 denote padding word
                    xi = pad_sequences([xi],maxlen=max_len,value=0,padding='post')[0]
                    yi = to_categorical([yi],num_classes=vocab_size)[0]
                    
                    X1.append(photo)
                    X2.append(xi)
                    y.append(yi)
                    
                if n==batch_size:
                    yield {'input_img':np.array(X1),'input_cap':np.array(X2)},np.array(y)
                    X1,X2,y = [],[],[]
                    n = 0

# %% [markdown]
# ## Word Embeddings

# %%
f = open("/kaggle/input/glove6b50dtxt/glove.6B.50d.txt",encoding='utf8')

# %%
embedding_index = {}

for line in f:
    values = line.split()
    
    word = values[0]
    word_embedding = np.array(values[1:],dtype='float')
    embedding_index[word] = word_embedding

# %%
f.close()

# %%
embedding_index['apple']
# Out:
# array([ 0.52042 , -0.8314  ,  0.49961 ,  1.2893  ,  0.1151  ,  0.057521,
#        -1.3753  , -0.97313 ,  0.18346 ,  0.47672 , -0.15112 ,  0.35532 ,
#         0.25912 , -0.77857 ,  0.52181 ,  0.47695 , -1.4251  ,  0.858   ,
#         0.59821 , -1.0903  ,  0.33574 , -0.60891 ,  0.41742 ,  0.21569 ,
#        -0.07417 , -0.5822  , -0.4502  ,  0.17253 ,  0.16448 , -0.38413 ,
#         2.3283  , -0.66682 , -0.58181 ,  0.74389 ,  0.095015, -0.47865 ,
#        -0.84591 ,  0.38704 ,  0.23693 , -1.5523  ,  0.64802 , -0.16521 ,
#        -1.4719  , -0.16224 ,  0.79857 ,  0.97391 ,  0.40027 , -0.21912 ,
#        -0.30938 ,  0.26581 ])

# %%
def get_embedding_matrix():
    emb_dim = 50
    matrix = np.zeros((vocab_size,emb_dim))
    for word,idx in word_to_idx.items():
        embedding_vector = embedding_index.get(word)
        
        if embedding_vector is not None:
            matrix[idx] = embedding_vector
            
    return matrix

# %%
embedding_matrix = get_embedding_matrix()
embedding_matrix.shape
# Out:
# (1848, 50)

# %%
#embedding_matrix[1847]

# %% [markdown]
# ### Model Architecture

# %%
input_img_features = Input(shape=(2048,),name='input_img')
inp_img1 = Dropout(0.3)(input_img_features)
inp_img2 = Dense(256,activation='relu')(inp_img1)

# %%
# Captions as Input
input_captions = Input(shape=(max_len,),name='input_cap')
inp_cap1 = Embedding(input_dim=vocab_size,output_dim=50,mask_zero=True)(input_captions)
inp_cap2 = Dropout(0.3)(inp_cap1)
inp_cap3 = LSTM(256)(inp_cap2)

# %%
decoder1 = add([inp_img2,inp_cap3])
decoder2 = Dense(256,activation='relu')(decoder1)
outputs = Dense(vocab_size,activation='softmax')(decoder2)

# Combined Model
model = Model(inputs=[input_img_features,input_captions],outputs=outputs)

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_cap (InputLayer)          [(None, 35)]         0
# __________________________________________________________________________________________________
# input_img (InputLayer)          [(None, 2048)]       0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 35, 50)       92400       input_cap[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2048)         0           input_img[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 35, 50)       0           embedding[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          524544      dropout[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 256)          314368      dropout_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 256)          0           dense[0][0]
#                                                                  lstm[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          65792       add[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1848)         474936      dense_1[0][0]
# ==================================================================================================
# Total params: 1,472,040
# Trainable params: 1,472,040
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Important Thing - Embedding Layer
model.layers[2].set_weights([embedding_matrix])
model.layers[2].trainable = False

# %%
model.compile(loss='categorical_crossentropy',optimizer="adam")

# %% [markdown]
# ### Training of Model

# %%
epochs = 10
number_pics_per_bath = 3
steps = len(train_descriptions)//number_pics_per_bath
print(steps)
# Out:
# 2000

# %%
for i in range(epochs):
    generator = data_generator(train_descriptions, encoding_train, word_to_idx, max_len, number_pics_per_bath)
    model.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
    model.save('./model_weights/model_' + str(i) + '.h5')
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 2000/2000 [==============================] - 451s 224ms/step - loss: 4.3018
# /opt/conda/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# 2000/2000 [==============================] - 442s 221ms/step - loss: 3.5860
# 2000/2000 [==============================] - 438s 219ms/step - loss: 3.3312
# 2000/2000 [==============================] - 440s 220ms/step - loss: 3.1738
# 2000/2000 [==============================] - 448s 224ms/step - loss: 3.0615
# 2000/2000 [==============================] - 453s 227ms/step - loss: 2.9783
# 2000/2000 [==============================] - 457s 229ms/step - loss: 2.9095
# 2000/2000 [==============================] - 446s 223ms/step - loss: 2.8573
# 2000/2000 [==============================] - 442s 221ms/step - loss: 2.8112
# 2000/2000 [==============================] - 437s 218ms/step - loss: 2.7727

# %%
def predict_caption(photo):
    
    in_text = "startseq"
    for i in range(max_len):
        sequence = [word_to_idx[w] for w in in_text.split() if w in word_to_idx]
        sequence = pad_sequences([sequence],maxlen=max_len,padding='post')
        
        ypred = model.predict([photo,sequence])
        ypred = ypred.argmax() #WOrd with max prob always - Greedy Sampling
        word = idx_to_word[ypred]
        in_text += (' ' + word)
        
        if word == "endseq":
            break
    
    final_caption = in_text.split()[1:-1]
    final_caption = ' '.join(final_caption)
    return final_caption

# %%
# Pick Some Random Images and See Results
plt.style.use("seaborn")
for i in range(15):
    idx = np.random.randint(0,1000)
    all_img_names = list(encoding_test.keys())
    img_name = all_img_names[idx]
    photo_2048 = encoding_test[img_name].reshape((1,2048))
    
    i = plt.imread("/kaggle/input/flickr8k/Flickr8k_Dataset/"+img_name+".jpg")
    
    caption = predict_caption(photo_2048)
    #print(caption)
    
    plt.title(caption)
    plt.imshow(i)
    plt.axis("off")
    plt.show()
